# %% [markdown]
# <a href="https://colab.research.google.com/github/harika268/Statistics_Practice/blob/main/Stats_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Student": ["Asha", "Ravi", "Kiran", "Meena", "Rahul"],
    "Marks": [85, 78, 92, 65, 88]
}

df = pd.DataFrame(data)
df
# Out:
#   Student  Marks
# 0    Asha     85
# 1    Ravi     78
# 2   Kiran     92
# 3   Meena     65
# 4   Rahul     88

# %%
print("Mean:", df["Marks"].mean())
print("Median:", df["Marks"].median())
print("Standard Deviation:", df["Marks"].std())
print("Variance:", df["Marks"].var())
print("Minimum:", df["Marks"].min())
print("Maximum:", df["Marks"].max())
# Out:
# Mean: 81.6
# Median: 85.0
# Standard Deviation: 10.597169433391164
# Variance: 112.30000000000001
# Minimum: 65
# Maximum: 92

# %%
plt.hist(df["Marks"], bins=5, edgecolor="black")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Distribution of Student Marks")
plt.show()
